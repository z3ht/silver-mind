# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
import tensorflow as tf

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

tf.compat.v1.disable_eager_execution()

# %%
import sys
import numpy as np

sys.path.append("..")

from silvermind import nnets

# %%
npz = np.load("../dataset/balanced_game_data.npz")
X = npz["arr_0"][:3000000]
y = npz["arr_1"][:3000000]

print(X.shape, y.shape)
# Out:
# (3000000, 5, 8, 8) (3000000,)

# %%
chess_cnn = nnets.DeepChess()
chess_cnn.train(X, y)
# Out:
# Train on 2900000 samples
# Epoch 1/5
# 2900000/2900000 [==============================] - 15s 5us/sample - loss: 0.0183 - mae: 0.0242
# Epoch 2/5
# 2900000/2900000 [==============================] - 14s 5us/sample - loss: 0.0167 - mae: 0.0184
# Epoch 3/5
# 2900000/2900000 [==============================] - 14s 5us/sample - loss: 0.0168 - mae: 0.0181
# Epoch 4/5
# 2900000/2900000 [==============================] - 14s 5us/sample - loss: 0.0168 - mae: 0.0179
# Epoch 5/5
# 2900000/2900000 [==============================] - 14s 5us/sample - loss: 0.0168 - mae: 0.0179
# Train on 2900000 samples
# Epoch 1/5
# 2900000/2900000 [==============================] - 12s 4us/sample - loss: 0.0594 - mae: 0.1550
# Epoch 2/5
# 2900000/2900000 [==============================] - 12s 4us/sample - loss: 0.0381 - mae: 0.1264
# Epoch 3/5
# 2900000/2900000 [==============================] - 12s 4us/sample - loss: 0.0380 - mae: 0.1261
# Epoch 4/5
# 2900000/2900000 [==============================] - 13s 4us/sample - loss: 0.0374 - mae: 0.1257
# Epoch 5/5
# 2900000/2900000 [==============================] - 12s 4us/sample - loss: 0.0320 - mae: 0.1218
# Train on 2900000 samples
# Epoch 1/5
# 2900000/2900000 [==============================] - 11s 4us/sample - loss: 0.0466 - mae: 0.0562
# Epoch 2/5
# 2900000/2900000 [==============================] - 11s 4us/sample - loss: 0.0420 - mae: 0.0426
# Epoch 3/5
# 2900000/2900000 [==============================] - 11s 4us/sample - loss: 0.0420 - mae: 0.0426
# Epoch 4/5
# 2900000/2900000 [==============================] - 10s 4us/sample - loss: 0.0420 - mae: 0.0426
# Epoch 5/5
# 2900000/2900000 [==============================] - 11s 4us/sample - loss: 0.0306 - mae: 0.0304
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 320)]        0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 320)]        0
# __________________________________________________________________________________________________
# sequential (Sequential)         (None, 100)          94400       input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 200)          0           sequential[0][0]
#                                                                  sequential[1][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 100)          20100       concatenate[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 100)          10100       dense_9[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 2)            202         dense_10[0][0]
# ==================================================================================================
# Total params: 124,802
# Trainable params: 30,402
# Non-trainable params: 94,400
# __________________________________________________________________________________________________
# Train on 700000 samples, validate on 100000 samples
# Epoch 1/10
# 700000/700000 [==============================] - 5s 7us/sample - loss: 0.0101 - mae: 0.0082 - val_loss: 1.7753e-05 - val_mae: 1.7762e-05
# Epoch 2/10
# 700000/700000 [==============================] - 5s 7us/sample - loss: 8.4577e-06 - mae: 8.4578e-06 - val_loss: 3.7527e-06 - val_mae: 3.7621e-06
# Epoch 3/10
# 700000/700000 [==============================] - 5s 7us/sample - loss: 2.2601e-06 - mae: 2.2603e-06 - val_loss: 1.3106e-06 - val_mae: 1.2948e-06
# Epoch 4/10
# 700000/700000 [==============================] - 5s 7us/sample - loss: 8.2892e-07 - mae: 8.3052e-07 - val_loss: 5.3610e-07 - val_mae: 5.2484e-07
# Epoch 5/10
# 700000/700000 [==============================] - 5s 7us/sample - loss: 3.4263e-07 - mae: 3.4459e-07 - val_loss: 2.3842e-07 - val_mae: 2.3049e-07
# Epoch 6/10
# 700000/700000 [==============================] - 5s 7us/sample - loss: 1.4146e-07 - mae: 1.4820e-07 - val_loss: 1.1921e-07 - val_mae: 1.1055e-07
# Epoch 7/10
# 700000/700000 [==============================] - 5s 7us/sample - loss: 6.4433e-08 - mae: 6.6759e-08 - val_loss: 0.0000e+00 - val_mae: 2.5343e-08
# Epoch 8/10
# 700000/700000 [==============================] - 5s 7us/sample - loss: 3.5286e-10 - mae: 1.9822e-08 - val_loss: 0.0000e+00 - val_mae: 1.2710e-08
# Epoch 9/10
# 700000/700000 [==============================] - 5s 7us/sample - loss: 0.0000e+00 - mae: 8.9445e-09 - val_loss: 0.0000e+00 - val_mae: 6.5016e-09
# Epoch 10/10
# 700000/700000 [==============================] - 5s 7us/sample - loss: 0.0000e+00 - mae: 5.3133e-09 - val_loss: 0.0000e+00 - val_mae: 4.1455e-09
# /usr/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '

# %%
chess_cnn.save("../../models/dc.tf")
# Out:
# INFO:tensorflow:Assets written to: ../../models/dc.tf/assets
